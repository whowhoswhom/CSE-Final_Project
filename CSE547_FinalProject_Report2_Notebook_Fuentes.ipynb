# %% [markdown]
# # CSE 547 Final Project — Report 2
#
# **Author:** Jose Fuentes
# **Course:** CSE 547
#
# This notebook documents the experimental work for **Parts 3, 4, 5, and 6** of the final project (RGB / IR object recognition on paired video scenes). Parts 1 and 2 are treated as validated baselines; they are referenced only for comparison against the Part 3, 4, and 6 models. All training was completed previously on a CUDA workstation; this notebook loads the cached JSON summaries, prediction CSVs, and result figures from the `figures/` and `manifests/` folders and renders them inline.
#
# The notebook is self-contained: it uses only the Python standard library, `pandas`, `matplotlib`, and `IPython.display`. It does not import any project module, does not load model checkpoints, and does not retrain or re-infer anything.

# %% [markdown]
# ## 1. Environment and helpers

# %%
import json
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, Markdown, display

# %matplotlib inline

pd.set_option("display.max_columns", 20)
pd.set_option("display.width", 140)
pd.set_option("display.float_format", lambda v: f"{v:.4f}")

FIGURES_DIR = Path("figures")
MANIFESTS_DIR = Path("manifests")

# %%
def load_json(name):
    """Load a JSON file from the figures/ folder."""
    with (FIGURES_DIR / name).open("r", encoding="utf-8") as fh:
        return json.load(fh)


def show_figure(name, caption=None):
    """Render a PNG from figures/ with an optional markdown caption."""
    if caption:
        display(Markdown(f"*{caption}*"))
    display(Image(filename=str(FIGURES_DIR / name)))


def best_of(run, key):
    """Pick the max value of a per-epoch history list (Part 3/4 runs store arrays)."""
    series = run.get(key)
    if series is None:
        return None
    if isinstance(series, list):
        return max(series) if series else None
    return series

# %% [markdown]
# ## 2. Dataset context
#
# The project uses paired RGB and thermal (IR) patches extracted from driving-scene videos across 8 object classes. Train / validation splits are defined at the **video** level to prevent leakage, and every manifest row stores the patch path, class label, source video, and split assignment. The table below is computed directly from the two manifest CSVs.

# %%
rgb_m = pd.read_csv(MANIFESTS_DIR / "rgb_manifest.csv", usecols=["modality", "class_name", "split"])
ir_m  = pd.read_csv(MANIFESTS_DIR / "ir_manifest.csv",  usecols=["modality", "class_name", "split"])


def manifest_summary(df, name):
    return {
        "modality": name,
        "total_patches": len(df),
        "train_patches": int((df["split"] == "train").sum()),
        "val_patches":   int((df["split"] == "val").sum()),
        "n_classes":     df["class_name"].nunique(),
    }


dataset_summary = pd.DataFrame([
    manifest_summary(rgb_m, "RGB"),
    manifest_summary(ir_m,  "IR"),
])
dataset_summary
# Out:
#   modality  total_patches  train_patches  val_patches  n_classes
# 0      RGB         108297          92161        16136          8
# 1       IR          52930          41801        11129          8

# %% [markdown]
# ## 3. Part 3 — RGB VGG16 transfer learning
#
# **Setup.** The Part 3 experiment reuses the ImageNet-pretrained VGG16 convolutional base with a two-layer dense classifier on top. Three freeze levels were trained: **F1** (freeze all conv blocks), **F2** (freeze everything except block5), and **F3** (freeze only blocks 1–3). The four-panel figure below compares train / validation accuracy and train / validation F1 across all three.

# %%
part3 = load_json("part3_rgb_vgg16_results.json")

part3_table = pd.DataFrame([
    {
        "label":         run["label"],
        "description":   run["description"],
        "freeze_level":  run["freeze_level"],
        "trainable_params": run["trainable_params"],
        "best_train_acc": best_of(run, "train_acc"),
        "best_val_acc":   best_of(run, "val_acc"),
        "best_train_f1":  best_of(run, "train_f1"),
        "best_val_f1":    best_of(run, "val_f1"),
    }
    for run in part3
])
part3_table = part3_table.sort_values("best_val_f1", ascending=False).reset_index(drop=True)
part3_table
# Out:
#   label              description  freeze_level  trainable_params  best_train_acc  best_val_acc  best_train_f1  best_val_f1
# 0    F3  train blocks 4-5 + head             3          13112584          1.0000        0.9475         1.0000       0.9466
# 1    F2     train block 5 + head             2           7212808          0.9978        0.9392         0.9978       0.9370
# 2    F1   freeze all conv blocks             1            133384          0.9467        0.8961         0.9458       0.8914

# %%
show_figure(
    "part3_rgb_vgg16_freeze.png",
    caption="Part 3 — VGG16 RGB freeze-level comparison (train/val accuracy and F1 across F1, F2, F3).",
)
# Out:
# *Part 3 — VGG16 RGB freeze-level comparison (train/val accuracy and F1 across F1, F2, F3).*

# %% [markdown]
# ## 4. Part 4 — IR convolutional autoencoder + dense classifier
#
# **Setup.** Six convolutional autoencoder architectures were trained on IR patches (varying conv depth, filter counts, and bottleneck dimension). Each frozen encoder was then used as a feature extractor for a two-layer dense classifier, under **two regularization settings** (a light dropout baseline and a stronger dropout + weight-decay variant), yielding **12 total configurations**. The four-panel figure reports train / validation accuracy and F1 across all twelve labeled options with different colors and a legend.

# %%
part4 = load_json("part4_ir_ae_results.json")

part4_table = pd.DataFrame([
    {
        "label":          run["label"],
        "ae_config":      run["ae_config"],
        "filters":        "-".join(str(f) for f in run["filters"]),
        "bottleneck_dim": run["bottleneck_dim"],
        "reg_config":     run["reg_config"],
        "dropout":        run["dropout"],
        "weight_decay":   run["weight_decay"],
        "best_train_acc": best_of(run, "train_acc"),
        "best_val_acc":   best_of(run, "val_acc"),
        "best_train_f1":  best_of(run, "train_f1"),
        "best_val_f1":    best_of(run, "val_f1"),
    }
    for run in part4
])
part4_table = part4_table.sort_values("best_val_f1", ascending=False).reset_index(drop=True)
part4_table
# Out:
#      label ae_config        filters  bottleneck_dim reg_config  dropout  weight_decay  best_train_acc  best_val_acc  best_train_f1  \
# 0   AE6-R1       AE6  32-64-128-256             512         R1   0.2000        0.0000          0.9282        0.8206         0.9249
# 1   AE6-R2       AE6  32-64-128-256             512         R2   0.5000        0.0001          0.8968        0.8200         0.8898
# 2   AE5-R1       AE5   16-32-64-128             256         R1   0.2000        0.0000          0.8925        0.8035         0.8853
# 3   AE2-R1       AE2          32-64             128         R1   0.2000        0.0000          0.8832        0.7967         0.8750
# 4   AE5-R2       AE5   16-32-64-128             256         R2   0.5000        0.0001          0.8555        0.7951         0.8434
# 5   AE4-R1       AE4      32-64-128             128         R1   0.2000        0.0000          0.8755        0.7894         0.8663
# 6   AE3-R1       AE3       16-32-64              64         R1   0.2000        0.0000          0.8569        0.7864         0.8462
# 7   AE1-R1       AE1          16-32              64         R1   0.2000        0.0000          0.8532        0.7845         0.8413
# 8   AE2-R2       AE2          32-64             128         R2   0.5000        0.0001          0.8449        0.7830         0.8309
# 9   AE4-R2       AE4      32-64-128             128         R2   0.5000        0.0001          0.8435        0.7820         0.8290
# 10  AE1-R2       AE1          16-32              64         R2   0.5000        0.0001          0.8239        0.7715         0.8060
# 11  AE3-R2       AE3       16-32-64              64         R2   0.5000        0.0001          0.8207        0.7705         0.8027
#
#     best_val_f1
# 0        0.7820
# 1        0.7779
# 2        0.7620
# 3        0.7542
# 4        0.7498
# 5        0.7463
# 6        0.7425
# 7        0.7398
# 8        0.7365
# 9        0.7362
# 10       0.7227
# 11       0.7221

# %%
show_figure(
    "part4_ir_autoencoder_12_options.png",
    caption="Part 4 — 12 AE + classifier combinations (train/val accuracy and F1 across labeled options).",
)
# Out:
# *Part 4 — 12 AE + classifier combinations (train/val accuracy and F1 across labeled options).*

# %% [markdown]
# ## 5. Part 6 — bounded refinement for blind-test readiness
#
# **Setup.** The strongest Part 3 RGB candidate received a short mild-augmentation refinement pass. On the IR side, none of the Part 4 autoencoder + classifier options came within 0.02 validation F1 of the Part 1 / Part 2 supervised IR CNN (Arch D), so IR refinement was skipped and the stronger supervised CNN was carried forward as the final IR model. All selection uses validation data only; no blind-test labels were consulted.

# %%
part6 = load_json("part6_refinement_results.json")

rgb_refined = part6["rgb_refined"]
ir_refined  = part6["ir_refined"]

part6_rows = []
if rgb_refined is not None:
    part6_rows.append({
        "sensor":           "RGB",
        "refined_label":    rgb_refined["label"],
        "best_train_acc":   rgb_refined.get("best_train_acc", best_of(rgb_refined, "train_acc")),
        "best_val_acc":     rgb_refined.get("best_val_acc",   best_of(rgb_refined, "val_acc")),
        "best_train_f1":    rgb_refined.get("best_train_f1",  best_of(rgb_refined, "train_f1")),
        "best_val_f1":      rgb_refined.get("best_val_f1",    best_of(rgb_refined, "val_f1")),
    })
if ir_refined is not None:
    part6_rows.append({
        "sensor":           "IR",
        "refined_label":    ir_refined["label"],
        "best_train_acc":   ir_refined.get("best_train_acc", best_of(ir_refined, "train_acc")),
        "best_val_acc":     ir_refined.get("best_val_acc",   best_of(ir_refined, "val_acc")),
        "best_train_f1":    ir_refined.get("best_train_f1",  best_of(ir_refined, "train_f1")),
        "best_val_f1":      ir_refined.get("best_val_f1",    best_of(ir_refined, "val_f1")),
    })
part6_table = pd.DataFrame(part6_rows)

print("Part 6 notes:")
for n in part6.get("notes", []):
    print(" -", n)
part6_table
# Out:
# Part 6 notes:
#  - IR AE did not come within 0.02 F1 of IR Part 1 Arch D; final IR uses the stronger supervised CNN reference.
#   sensor      refined_label  best_train_acc  best_val_acc  best_train_f1  best_val_f1
# 0    RGB  RGB VGG16 refined          0.9955        0.9498         0.9955       0.9480

# %% [markdown]
# ## 6. Final model selection
#
# Final RGB and IR models are chosen by **validation F1 only**, drawing candidates from Part 1 baselines, Part 2 regularized variants, Part 3 (RGB transfer learning), Part 4 (IR autoencoders), and Part 6 refinement. The candidates table below lists every contender considered; the two-row headline table shows the final picks used for the blind-test submission.

# %%
selection = load_json("report2_final_model_selection.json")


def format_train(value):
    """Render train metrics that were not logged (stored as 0 / None) as 'n/a'."""
    if value is None or value == 0.0 or value == 0:
        return "n/a"
    return value


candidate_cols = ["modality", "source", "label", "arch", "kind", "best_train_acc", "best_val_acc", "best_train_f1", "best_val_f1"]
candidates = pd.DataFrame(
    selection["rgb_candidates"] + selection["ir_candidates"]
)[candidate_cols]
candidates = candidates.sort_values(["modality", "best_val_f1"], ascending=[True, False]).reset_index(drop=True)
for col in ("best_train_acc", "best_train_f1"):
    candidates[col] = candidates[col].apply(format_train)
candidates
# Out:
#    modality             source                   label arch           kind best_train_acc  best_val_acc best_train_f1  best_val_f1
# 0        IR     part2_ir_aug_2  IR CNN Arch D + Aug L2    D            cnn            n/a        0.9263           n/a       0.9227
# 1        IR     part1_ir_archD        IR Part 1 Arch D    D            cnn         0.9766        0.8880        0.9772       0.8792
# 2        IR       part4_AE6-R1               IR AE6-R1  NaN  ae_classifier         0.9420        0.8206        0.9389       0.7820
# 3        IR       part4_AE6-R2               IR AE6-R2  NaN  ae_classifier         0.9234        0.8200        0.9167       0.7779
# 4        IR       part4_AE5-R1               IR AE5-R1  NaN  ae_classifier         0.9068        0.8035        0.9000       0.7620
# 5        IR       part4_AE2-R1               IR AE2-R1  NaN  ae_classifier         0.8953        0.7965        0.8865       0.7542
# 6        IR       part4_AE5-R2               IR AE5-R2  NaN  ae_classifier         0.8736        0.7951        0.8608       0.7498
# 7        IR       part4_AE4-R1               IR AE4-R1  NaN  ae_classifier         0.8873        0.7894        0.8768       0.7463
# 8        IR       part4_AE3-R1               IR AE3-R1  NaN  ae_classifier         0.8733        0.7864        0.8621       0.7425
# 9        IR       part4_AE1-R1               IR AE1-R1  NaN  ae_classifier         0.8668        0.7845        0.8541       0.7398
# 10       IR       part4_AE2-R2               IR AE2-R2  NaN  ae_classifier         0.8701        0.7830        0.8562       0.7365
# 11       IR       part4_AE4-R2               IR AE4-R2  NaN  ae_classifier         0.8700        0.7820        0.8558       0.7362
# 12       IR       part4_AE1-R2               IR AE1-R2  NaN  ae_classifier         0.8469        0.7715        0.8283       0.7227
# 13       IR       part4_AE3-R2               IR AE3-R2  NaN  ae_classifier         0.8406        0.7704        0.8223       0.7221
# 14      RGB  part6_rgb_refined       RGB VGG16 refined  NaN          vgg16         0.9955        0.9498        0.9955       0.9480
# 15      RGB           part3_F3            RGB VGG16 F3  NaN          vgg16         0.9999        0.9475        0.9999       0.9466
# 16      RGB           part3_F2            RGB VGG16 F2  NaN          vgg16         0.9941        0.9392        0.9941       0.9370
# 17      RGB    part1_rgb_archD       RGB Part 1 Arch D    D            cnn         0.9999        0.9201        0.9999       0.9185
# 18      RGB           part3_F1            RGB VGG16 F1  NaN          vgg16         0.9547        0.8961        0.9539       0.8914

# %%
final_rgb = selection["final_rgb"]
final_ir  = selection["final_ir"]

headline = pd.DataFrame([
    {
        "sensor":         "RGB",
        "final_label":    final_rgb["label"],
        "best_train_acc": format_train(final_rgb.get("best_train_acc", best_of(final_rgb, "train_acc"))),
        "best_val_acc":   final_rgb.get("best_val_acc",   best_of(final_rgb, "val_acc")),
        "best_train_f1":  format_train(final_rgb.get("best_train_f1",  best_of(final_rgb, "train_f1"))),
        "best_val_f1":    final_rgb.get("best_val_f1",    best_of(final_rgb, "val_f1")),
    },
    {
        "sensor":         "IR",
        "final_label":    final_ir["label"],
        "best_train_acc": format_train(final_ir.get("best_train_acc", best_of(final_ir, "train_acc"))),
        "best_val_acc":   final_ir.get("best_val_acc",   best_of(final_ir, "val_acc")),
        "best_train_f1":  format_train(final_ir.get("best_train_f1",  best_of(final_ir, "train_f1"))),
        "best_val_f1":    final_ir.get("best_val_f1",    best_of(final_ir, "val_f1")),
    },
])
headline
# Out:
#   sensor             final_label best_train_acc  best_val_acc best_train_f1  best_val_f1
# 0    RGB       RGB VGG16 refined         0.9955        0.9498        0.9955       0.9480
# 1     IR  IR CNN Arch D + Aug L2            n/a        0.9263           n/a       0.9227

# %% [markdown]
# ## 7. Part 5 — error analysis and sensor comparison
#
# Using the final RGB and IR models, every validation sample was scored and stored in `figures/part5_rgb_predictions.csv` and `figures/part5_ir_predictions.csv`. The analysis below is built directly from those CSVs and the cached Part 5 summary JSON; no inference is re-run.

# %%
rgb_preds = pd.read_csv(FIGURES_DIR / "part5_rgb_predictions.csv")
ir_preds  = pd.read_csv(FIGURES_DIR / "part5_ir_predictions.csv")

overall = pd.DataFrame([
    {
        "sensor":      "RGB",
        "n_val":       len(rgb_preds),
        "val_acc":     rgb_preds["correct"].mean(),
        "n_miss":      int((~rgb_preds["correct"]).sum()),
    },
    {
        "sensor":      "IR",
        "n_val":       len(ir_preds),
        "val_acc":     ir_preds["correct"].mean(),
        "n_miss":      int((~ir_preds["correct"]).sum()),
    },
])
overall
# Out:
#   sensor  n_val  val_acc  n_miss
# 0    RGB  16136   0.9498     810
# 1     IR  11129   0.9265     818

# %%
def miss_by_class(df, sensor):
    grouped = df[~df["correct"]].groupby("true_class").size().rename(f"{sensor}_misclassified")
    return grouped.to_frame().reset_index()


rgb_miss = miss_by_class(rgb_preds, "RGB").sort_values("RGB_misclassified", ascending=False).reset_index(drop=True)
ir_miss  = miss_by_class(ir_preds,  "IR") .sort_values("IR_misclassified",  ascending=False).reset_index(drop=True)

miss_table = rgb_miss.merge(ir_miss, on="true_class", how="outer").fillna(0).astype({"RGB_misclassified": int, "IR_misclassified": int})
miss_table
# Out:
#   true_class  RGB_misclassified  IR_misclassified
# 0       bike                 90                36
# 1        bus                130               436
# 2        car                127               117
# 3      light                120                24
# 4      motor                 74                16
# 5     person                 76                41
# 6       sign                 66                90
# 7      truck                127                58

# %%
show_figure(
    "part5_rgb_misclassified_by_class.png",
    caption="Part 5 — up to two RGB misclassifications per class (highest-confidence errors).",
)
# Out:
# *Part 5 — up to two RGB misclassifications per class (highest-confidence errors).*

# %%
show_figure(
    "part5_ir_misclassified_by_class.png",
    caption="Part 5 — up to two IR misclassifications per class (highest-confidence errors).",
)
# Out:
# *Part 5 — up to two IR misclassifications per class (highest-confidence errors).*

# %%
analysis = load_json("part5_analysis_summary.json")

paired = pd.DataFrame([
    {"scenario": "RGB correct, IR wrong", "count": analysis["rgb_correct_ir_wrong_count"]},
    {"scenario": "IR correct, RGB wrong", "count": analysis["ir_correct_rgb_wrong_count"]},
])
paired
# Out:
#                 scenario  count
# 0  RGB correct, IR wrong      2
# 1  IR correct, RGB wrong      3

# %%
show_figure(
    "part5_rgb_correct_ir_wrong.png",
    caption="Paired validation scenes where the RGB model was correct and the IR model was wrong.",
)
# Out:
# *Paired validation scenes where the RGB model was correct and the IR model was wrong.*

# %%
show_figure(
    "part5_ir_correct_rgb_wrong.png",
    caption="Paired validation scenes where the IR model was correct and the RGB model was wrong.",
)
# Out:
# *Paired validation scenes where the IR model was correct and the RGB model was wrong.*

# %% [markdown]
# ### Justification for misclassifications and sensor reliability
#
# RGB generally wins on classes that depend on **color and fine texture** — traffic signs, signal lights, and small objects whose shape cues are weak in a thermal view. IR pulls ahead in **low-light or visually cluttered** scenes where visible contrast collapses but thermal contrast against the background remains strong (vehicles, pedestrians at night, vehicles partially behind foliage). The largest single IR error cluster is **bus** (436 misclassifications), consistent with the IR sensor struggling to disambiguate large vehicles of similar thermal signature; RGB, in contrast, spreads its errors more evenly across classes. The paired-scene grids above illustrate these trade-offs concretely.

# %% [markdown]
# ## 8. Integrity and blind-test statement
#
# Final models were selected exclusively on **validation F1**. No blind-test labels were consulted during training, hyperparameter selection, Part 5 analysis, or Part 6 refinement. The two rows in the headline table in Section 6 (**RGB VGG16 refined** and **IR CNN Arch D + Aug L2**) are the models submitted for the April-24 blind-test evaluation. No withheld-test images participated in any training or selection step.

# %% [markdown]
# ## 9. References
#
# - Written report: `CSE547_FinalProject_Report2_Fuentes.pdf` (5 pages).
# - Training / evaluation / plotting source code: `report2_pipeline.py` in this project folder (not   imported by this notebook, but available for inspection).
# - Cached result artifacts used by every cell above: JSON summaries and PNG figures under `figures/`,   prediction CSVs `figures/part5_rgb_predictions.csv` and `figures/part5_ir_predictions.csv`, and   manifests `manifests/rgb_manifest.csv` / `manifests/ir_manifest.csv`.
# - The 10-minute video walkthrough is linked on Blackboard.
